# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
#     # Draw face connections
#     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
#                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
#                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                              ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
#     # Draw left hand connections
#     mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                              mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
#                              mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
#                              ) 
#     # Draw right hand connections  
#     mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
#                              mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
#                              )

# %%
cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-beea7e0dea11> in <module>
#       1 pose = []
# ----> 2 for res in results.pose_landmarks.landmark:
#       3     test = np.array([res.x, res.y, res.z, res.visibility])
#       4     pose.append(test)
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['{}'.format(i) for i in range(0, 5)])

# Thirty videos worth of data
no_sequences = 20

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
default_n = 20
# for action in actions: 
#     for sequence in range(no_sequences + default_n):
#         try: 
#             os.makedirs(os.path.join(DATA_PATH, action, str(sequence + default_n)))
#         except:
#             pass

# %%
# cap = cv2.VideoCapture(1)
# # Set mediapipe model 
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
#     # NEW LOOP
#         action = '4'
#         # Loop through sequences aka videos
#         for sequence in range(default_n, no_sequences + default_n):
#             # Loop through video length aka sequence length
#             for frame_num in range(sequence_length):

#                 # Read feed
#                 ret, frame = cap.read()

#                 # Make detections
#                 image, results = mediapipe_detection(frame, holistic)
# #                 print(results)

#                 # Draw landmarks
#                 draw_styled_landmarks(image, results)
                
#                 # NEW Apply wait logic
#                 if frame_num == 0: 
#                     cv2.putText(image, 'STARTING COLLECTION', (120,200), 
#                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
#                     cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
#                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
#                     # Show to screen
#                     cv2.imshow('OpenCV Feed', image)
#                     cv2.waitKey(5000)
#                 else: 
#                     cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
#                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
#                     # Show to screen
#                     cv2.imshow('OpenCV Feed', image)
                
#                 # NEW Export keypoints
#                 keypoints = extract_keypoints(results)
#                 npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
#                 np.save(npy_path, keypoints)

#                 # Break gracefully
#                 if cv2.waitKey(10) & 0xFF == ord('q'):
#                     break
                    
#         cap.release()
#         cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
actions = np.array(['{}'.format(i) for i in range(0, 5)])
label_map = {label:num for num, label in enumerate(actions)}

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['{}'.format(i) for i in range(0, 5)])

sequences, labels = [], []
no_sequences = 20
sequence_length = 30
for action in actions:
    for sequence in range(no_sequences + default_n):
        window = []
        for frame_num in range(sequence_length):
            try:
                res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
                
            except:
                print('no data ', action, sequence, frame_num)
                res = np.zeros((258))
            window.append(res)
            
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
X.shape
# Out:
# (200, 30, 258)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
import tensorflow as tf

# %%
from keras.callbacks import CSVLogger
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)
csv_logger = CSVLogger(f'logs.log', separator=',', append=False)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,258)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[csv_logger])
# model = tf.keras.models.load_model('action.h5')
# Out:
# Epoch 1/100
# 6/6 [==============================] - 4s 40ms/step - loss: 1.5985 - categorical_accuracy: 0.2421
# Epoch 2/100
# 6/6 [==============================] - 0s 39ms/step - loss: 1.4775 - categorical_accuracy: 0.2789
# Epoch 3/100
# 6/6 [==============================] - 0s 39ms/step - loss: 1.5288 - categorical_accuracy: 0.4000
# Epoch 4/100
# 6/6 [==============================] - 0s 39ms/step - loss: 1.2822 - categorical_accuracy: 0.3895
# Epoch 5/100
# 6/6 [==============================] - 0s 40ms/step - loss: 1.3377 - categorical_accuracy: 0.4842
# Epoch 6/100
# 6/6 [==============================] - 0s 42ms/step - loss: 1.3984 - categorical_accuracy: 0.4000
# Epoch 7/100
# 6/6 [==============================] - 0s 49ms/step - loss: 1.2286 - categorical_accuracy: 0.4421
# Epoch 8/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.9970 - categorical_accuracy: 0.5895
# Epoch 9/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.8775 - categorical_accuracy: 0.6947
# Epoch 10/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.9066 - categorical_accuracy: 0.6579
# Epoch 11/100
# 6/6 [==============================] - 0s 55ms/step - loss: 0.6347 - categorical_accuracy: 0.7632
# Epoch 12/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.6208 - categorical_accuracy: 0.7474
# Epoch 13/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.8110 - categorical_accuracy: 0.6895
# Epoch 14/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4491 - categorical_accuracy: 0.8789
# Epoch 15/100
# 6/6 [==============================] - 0s 44ms/step - loss: 1.1687 - categorical_accuracy: 0.5947
# Epoch 16/100
# 6/6 [==============================] - 0s 43ms/step - loss: 1.0206 - categorical_accuracy: 0.6263
# Epoch 17/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.9247 - categorical_accuracy: 0.6895
# Epoch 18/100
# 6/6 [==============================] - 0s 53ms/step - loss: 0.4805 - categorical_accuracy: 0.9211
# Epoch 19/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3635 - categorical_accuracy: 0.8421
# Epoch 20/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.5327 - categorical_accuracy: 0.8737
# Epoch 21/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2939 - categorical_accuracy: 0.9526
# Epoch 22/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.4538 - categorical_accuracy: 0.8895
# Epoch 23/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3336 - categorical_accuracy: 0.9421
# Epoch 24/100
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1606 - categorical_accuracy: 0.9474
# Epoch 25/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1204 - categorical_accuracy: 0.9526
# Epoch 26/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0823 - categorical_accuracy: 0.9684
# Epoch 27/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1097 - categorical_accuracy: 0.9632
# Epoch 28/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1089 - categorical_accuracy: 0.9789
# Epoch 29/100
# 6/6 [==============================] - 0s 44ms/step - loss: 0.0614 - categorical_accuracy: 0.9895
# Epoch 30/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0773 - categorical_accuracy: 0.9895
# Epoch 31/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1823 - categorical_accuracy: 0.9526
# Epoch 32/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2137 - categorical_accuracy: 0.9211
# Epoch 33/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1925 - categorical_accuracy: 0.9579
# Epoch 34/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0774 - categorical_accuracy: 0.9947
# Epoch 35/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0647 - categorical_accuracy: 0.9895
# Epoch 36/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0428 - categorical_accuracy: 0.9842
# Epoch 37/100
# 6/6 [==============================] - 0s 44ms/step - loss: 0.0299 - categorical_accuracy: 1.0000
# Epoch 38/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0232 - categorical_accuracy: 0.9895
# Epoch 39/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0174 - categorical_accuracy: 1.0000
# Epoch 40/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0074 - categorical_accuracy: 1.0000
# Epoch 41/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 42/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 43/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 44/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 45/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 46/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 47/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 48/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 49/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 50/100
# 6/6 [==============================] - 0s 41ms/step - loss: 9.4392e-04 - categorical_accuracy: 1.0000
# Epoch 51/100
# 6/6 [==============================] - 0s 43ms/step - loss: 8.3339e-04 - categorical_accuracy: 1.0000
# Epoch 52/100
# 6/6 [==============================] - 0s 44ms/step - loss: 7.7875e-04 - categorical_accuracy: 1.0000
# Epoch 53/100
# 6/6 [==============================] - 0s 43ms/step - loss: 6.8966e-04 - categorical_accuracy: 1.0000
# Epoch 54/100
# 6/6 [==============================] - 0s 42ms/step - loss: 6.1566e-04 - categorical_accuracy: 1.0000
# Epoch 55/100
# 6/6 [==============================] - 0s 42ms/step - loss: 5.6916e-04 - categorical_accuracy: 1.0000
# Epoch 56/100
# 6/6 [==============================] - 0s 40ms/step - loss: 5.0925e-04 - categorical_accuracy: 1.0000
# Epoch 57/100
# 6/6 [==============================] - 0s 40ms/step - loss: 4.9758e-04 - categorical_accuracy: 1.0000
# Epoch 58/100
# 6/6 [==============================] - 0s 48ms/step - loss: 4.3457e-04 - categorical_accuracy: 1.0000
# Epoch 59/100
# 6/6 [==============================] - 0s 40ms/step - loss: 4.0180e-04 - categorical_accuracy: 1.0000
# Epoch 60/100
# 6/6 [==============================] - 0s 39ms/step - loss: 3.7205e-04 - categorical_accuracy: 1.0000
# Epoch 61/100
# 6/6 [==============================] - 0s 39ms/step - loss: 3.5050e-04 - categorical_accuracy: 1.0000
# Epoch 62/100
# 6/6 [==============================] - 0s 44ms/step - loss: 3.3671e-04 - categorical_accuracy: 1.0000
# Epoch 63/100
# 6/6 [==============================] - 1s 127ms/step - loss: 3.0905e-04 - categorical_accuracy: 1.0000
# Epoch 64/100
# 6/6 [==============================] - 0s 46ms/step - loss: 2.8454e-04 - categorical_accuracy: 1.0000
# Epoch 65/100
# 6/6 [==============================] - 0s 47ms/step - loss: 2.6785e-04 - categorical_accuracy: 1.0000
# Epoch 66/100
# 6/6 [==============================] - 0s 44ms/step - loss: 2.4774e-04 - categorical_accuracy: 1.0000
# Epoch 67/100
# 6/6 [==============================] - 0s 46ms/step - loss: 2.3238e-04 - categorical_accuracy: 1.0000
# Epoch 68/100
# 6/6 [==============================] - 0s 43ms/step - loss: 2.2570e-04 - categorical_accuracy: 1.0000
# Epoch 69/100
# 6/6 [==============================] - 0s 42ms/step - loss: 2.0667e-04 - categorical_accuracy: 1.0000
# Epoch 70/100
# 6/6 [==============================] - 0s 40ms/step - loss: 1.9424e-04 - categorical_accuracy: 1.0000
# Epoch 71/100
# 6/6 [==============================] - 0s 35ms/step - loss: 1.8260e-04 - categorical_accuracy: 1.0000
# Epoch 72/100
# 6/6 [==============================] - 0s 40ms/step - loss: 1.7512e-04 - categorical_accuracy: 1.0000
# Epoch 73/100
# 6/6 [==============================] - 0s 40ms/step - loss: 1.6261e-04 - categorical_accuracy: 1.0000
# Epoch 74/100
# 6/6 [==============================] - 0s 42ms/step - loss: 1.5536e-04 - categorical_accuracy: 1.0000
# Epoch 75/100
# 6/6 [==============================] - 0s 40ms/step - loss: 1.4704e-04 - categorical_accuracy: 1.0000
# Epoch 76/100
# 6/6 [==============================] - 0s 40ms/step - loss: 1.3857e-04 - categorical_accuracy: 1.0000
# Epoch 77/100
# 6/6 [==============================] - 0s 39ms/step - loss: 1.3105e-04 - categorical_accuracy: 1.0000
# Epoch 78/100
# 6/6 [==============================] - 0s 39ms/step - loss: 1.2742e-04 - categorical_accuracy: 1.0000
# Epoch 79/100
# 6/6 [==============================] - 0s 38ms/step - loss: 1.1923e-04 - categorical_accuracy: 1.0000
# Epoch 80/100
# 6/6 [==============================] - 0s 38ms/step - loss: 1.1350e-04 - categorical_accuracy: 1.0000
# Epoch 81/100
# 6/6 [==============================] - 0s 38ms/step - loss: 1.0975e-04 - categorical_accuracy: 1.0000
# Epoch 82/100
# 6/6 [==============================] - 0s 38ms/step - loss: 1.0422e-04 - categorical_accuracy: 1.0000
# Epoch 83/100
# 6/6 [==============================] - 0s 38ms/step - loss: 9.9408e-05 - categorical_accuracy: 1.0000
# Epoch 84/100
# 6/6 [==============================] - 0s 38ms/step - loss: 9.4774e-05 - categorical_accuracy: 1.0000
# Epoch 85/100
# 6/6 [==============================] - 0s 38ms/step - loss: 9.1155e-05 - categorical_accuracy: 1.0000
# Epoch 86/100
# 6/6 [==============================] - 0s 38ms/step - loss: 8.7091e-05 - categorical_accuracy: 1.0000
# Epoch 87/100
# 6/6 [==============================] - 0s 38ms/step - loss: 8.4678e-05 - categorical_accuracy: 1.0000
# Epoch 88/100
# 6/6 [==============================] - 0s 38ms/step - loss: 8.1123e-05 - categorical_accuracy: 1.0000
# Epoch 89/100
# 6/6 [==============================] - 0s 38ms/step - loss: 7.8703e-05 - categorical_accuracy: 1.0000
# Epoch 90/100
# 6/6 [==============================] - 0s 45ms/step - loss: 7.7248e-05 - categorical_accuracy: 1.0000
# Epoch 91/100
# 6/6 [==============================] - 0s 40ms/step - loss: 7.2234e-05 - categorical_accuracy: 1.0000
# Epoch 92/100
# 6/6 [==============================] - 0s 43ms/step - loss: 7.0314e-05 - categorical_accuracy: 1.0000
# Epoch 93/100
# 6/6 [==============================] - 0s 48ms/step - loss: 6.7813e-05 - categorical_accuracy: 1.0000
# Epoch 94/100
# 6/6 [==============================] - 0s 51ms/step - loss: 6.6579e-05 - categorical_accuracy: 1.0000
# Epoch 95/100
# 6/6 [==============================] - 0s 51ms/step - loss: 6.3140e-05 - categorical_accuracy: 1.0000
# Epoch 96/100
# 6/6 [==============================] - 0s 47ms/step - loss: 6.1134e-05 - categorical_accuracy: 1.0000
# Epoch 97/100
# 6/6 [==============================] - 0s 51ms/step - loss: 5.9442e-05 - categorical_accuracy: 1.0000
# Epoch 98/100
# 6/6 [==============================] - 0s 47ms/step - loss: 5.7357e-05 - categorical_accuracy: 1.0000
# Epoch 99/100
# 6/6 [==============================] - 0s 52ms/step - loss: 5.5992e-05 - categorical_accuracy: 1.0000
# Epoch 100/100
# 6/6 [==============================] - 0s 53ms/step - loss: 5.4224e-05 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30, 64)            82688
#
#  lstm_4 (LSTM)               (None, 30, 128)           98816
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 237,317
# Trainable params: 237,317
# Non-trainable params: 0
# _________________________________________________________________

# %%
import pandas as pd

log_file = 'logs.log'
history = pd.read_csv(log_file, sep=r',', header=[0], engine='python')

# %%
loss = history['loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history['categorical_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[2])]
# Out:
# '2'

# %%
actions[np.argmax(y_test[2])]
# Out:
# '2'

# %%
score = 0
for r, y in zip(res, y_test):
    if np.argmax(r) == np.argmax(y):
        score += 1
        
print(score)
# Out:
# 10

# %%
# model.save('action.h5')

# %%
colors = [(245,117,16), (117,245,16), (16,117,245), (116,17,245), (200,200,5)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.5

cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]
                
            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 0
